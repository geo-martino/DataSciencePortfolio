# %% [markdown]
# Work in progress (WIP)

# %% [markdown]
# ## Analysing web traffic data from jorjmakesmusic.com

# %% [markdown]
# Obtained traffic data in .csv from wix relating to traffic from the jorjmakesmusic.com website. Cleaned data and showed points of interest on graphs.

# %% [markdown]
# Import all necessary packages, set pandas options and open csv. All columns start with 'Traffic ' so have removed this from each column for better code legibility.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

f = open('input/jorjmakesmusic_traffic.csv')
traffic_raw = pd.read_csv(f)

traffic_raw.rename(columns=lambda x: x[8:], inplace=True)
traffic_raw.head(20)
# Out:
#            Day New or Returning Visitor Referring Category Ø Referring Site Ø  \
# 0   20/05/2020        Returning Visitor               Direct           Direct
# 1   22/05/2020        Returning Visitor               Direct           Direct
# 2   05/05/2020              New Visitor               Social     facebook.com
# 3   05/05/2020              New Visitor               Social     facebook.com
# 4   05/05/2020              New Visitor               Social     facebook.com
# 5   07/10/2020              New Visitor       Organic Search       google.com
# 6   05/05/2020              New Visitor               Social     facebook.com
# 7   04/01/2021              New Visitor               Direct           Direct
# 8   23/05/2020        Returning Visitor               Direct           Direct
# 9   07/06/2020        Returning Visitor               Direct           Direct
# 10  10/12/2020              New Visitor               Social     facebook.com
# 11  20/06/2020        Returning Visitor  Wix Email Marketing              NaN
# 12  17/11/2020              New Visitor               Social     facebook.com
# 13  01/05/2020        Returning Visitor               Direct           Direct
# 14  19/10/2020              New Visitor       Organic Search       google.com
# 15  01/11/2020              New Visitor       Organic Search        baidu.com
# 16  02/05/2020        Returning Visitor               Direct           Direct
# 17  05/05/2020              New Visitor               Social     facebook.com
# 18  05/05/2020              New Visitor               Direct           Direct
# 19  01/05/2020        Returning Visitor               Direct           Direct
#
#               Referring URL                   UTM Campaign Name Ø  \
# 0                       NaN                                     _
# 1                       NaN                                     _
# 2     http://m.facebook.com                                     _
# 3    http://m.facebook.com/                                     _
# 4    http://m.facebook.com/                                     _
# 5       https://google.com/                                     _
# 6   https://m.facebook.com/                                     _
# 7                       NaN                                     _
# 8                       NaN                                     _
# 9                       NaN                                     _
# 10  https://l.facebook.com/                                     _
# 11                      NaN  d5328aae-be6f-4dbc-a1c5-9886f145f202
# 12  https://l.facebook.com/                                     _
# 13                      NaN                                     _
# 14      https://google.com/                                     _
# 15        http://baidu.com/                                     _
# 16                      NaN                                     _
# 17   http://m.facebook.com/                                     _
# 18                      NaN                                     _
# 19                      NaN                                     _
#
#    UTM Campaign Medium Ø UTM Campaign Source Ø    Page Path Ø  \
# 0                      _                     _      /maturity
# 1                      _                     _  /early-access
# 2                      _                     _              /
# 3                      _                     _         /video
# 4                      _                     _              /
# 5                      _                     _         /video
# 6                      _                     _         /video
# 7                      _                     _              /
# 8                      _                     _              /
# 9                      _                     _     /exclusive
# 10                     _                     _         /video
# 11                  mail                    so  /early-access
# 12                     _                     _      /maturity
# 13                     _                     _         /video
# 14                     _                     _      /maturity
# 15                     _                     _              /
# 16                     _                     _              /
# 17                     _                     _              /
# 18                     _                     _              /
# 19                     _                     _      /maturity
#
#                                              Page URL         Country Region  \
# 0                  http://jorjmakesmusic.com/maturity  United Kingdom    ENG
# 1              http://jorjmakesmusic.com/early-access  United Kingdom    GRE
# 2                           http://jorjmakesmusic.com  United Kingdom    BNH
# 3                     http://jorjmakesmusic.com/video  United Kingdom    BNH
# 4                           http://jorjmakesmusic.com  United Kingdom    BNH
# 5                    https://jorjmakesmusic.com/video         Germany     BE
# 6                     http://jorjmakesmusic.com/video  United Kingdom    ENG
# 7                          https://jorjmakesmusic.com             NaN    NaN
# 8                           http://jorjmakesmusic.com  United Kingdom    GRE
# 9                 http://jorjmakesmusic.com/exclusive  United Kingdom    LEW
# 10                   https://jorjmakesmusic.com/video  United Kingdom    BNH
# 11  http://jorjmakesmusic.com/early-access?utm_cam...  United Kingdom    LEW
# 12                https://jorjmakesmusic.com/maturity  United Kingdom    BNH
# 13                    http://jorjmakesmusic.com/video  United Kingdom    LEW
# 14                https://jorjmakesmusic.com/maturity  United Kingdom    GLG
# 15                         https://jorjmakesmusic.com           China     SH
# 16                          http://jorjmakesmusic.com  United Kingdom    LEW
# 17                          http://jorjmakesmusic.com  United Kingdom    SWK
# 18                          http://jorjmakesmusic.com  United Kingdom    ISL
# 19                 http://jorjmakesmusic.com/maturity  United Kingdom    LEW
#
#           City Device Type Browser Browser Version Operating System  \
# 0       London     Desktop  Chrome   81.0.4044.138          Windows
# 1    Greenwich     Desktop  Chrome   81.0.4044.138          Windows
# 2     Brighton      Mobile  Safari             NaN           Mac OS
# 3     Brighton      Mobile  Chrome  268.1.0.54.121          Android
# 4     Brighton      Mobile  Chrome  268.1.0.54.121          Android
# 5       Berlin     Desktop  Chrome   83.0.4103.116            Linux
# 6       London      Mobile  Chrome   81.0.4044.117          Android
# 7          NaN     Desktop  Chrome     71.0.3563.0            Linux
# 8    Greenwich     Desktop  Chrome   81.0.4044.138          Windows
# 9          NaN     Desktop  Chrome    83.0.4103.97          Windows
# 10    Brighton     Desktop  Chrome    87.0.4280.88           Mac OS
# 11         NaN     Desktop  Chrome   83.0.4103.106          Windows
# 12    Brighton     Desktop  Chrome   86.0.4240.198           Mac OS
# 13         NaN     Desktop  Chrome   81.0.4044.129          Windows
# 14     Glasgow      Tablet  Chrome    85.0.4183.92              iOS
# 15     Hongkou      Mobile  Chrome   57.0.2987.108          Android
# 16         NaN      Mobile  Chrome   81.0.4044.117          Android
# 17  Bermondsey      Mobile  Chrome  268.1.0.54.121          Android
# 18   Islington      Mobile  Safari          13.0.5           Mac OS
# 19         NaN     Desktop  Chrome   81.0.4044.129          Windows
#
#    Is the First Page Viewed Ø (Yes / No) Is the Last Page Viewed Ø (Yes / No)  \
# 0                                    Yes                                  Yes
# 1                                    Yes                                   No
# 2                                    Yes                                  Yes
# 3                                     No                                  Yes
# 4                                    Yes                                   No
# 5                                     No                                   No
# 6                                     No                                  Yes
# 7                                    Yes                                  Yes
# 8                                     No                                  Yes
# 9                                    Yes                                  Yes
# 10                                    No                                   No
# 11                                   Yes                                   No
# 12                                    No                                   No
# 13                                    No                                   No
# 14                                    No                                   No
# 15                                   Yes                                  Yes
# 16                                   Yes                                   No
# 17                                   Yes                                  Yes
# 18                                   Yes                                   No
# 19                                    No                                   No
#
#    Next Page Viewed Ø Previous Page Viewed Ø  Page Views  Site Sessions Ø  \
# 0                 NaN                    NaN           7                1
# 1          /exclusive                    NaN           5                1
# 2                 NaN                    NaN           4                2
# 3                 NaN                      /           3                2
# 4              /video                    NaN           3                2
# 5               /news              /maturity           3                1
# 6                 NaN                      /           3                1
# 7                 NaN                    NaN           2                2
# 8                 NaN              /maturity           2                1
# 9                 NaN                    NaN           2                1
# 10             /about                      /           2                1
# 11         /exclusive                    NaN           2                1
# 12             /video                      /           2                1
# 13          /maturity                  /news           2                1
# 14             /video                      /           2                1
# 15                NaN                    NaN           2                2
# 16          /maturity                    NaN           2                1
# 17                NaN                    NaN           2                1
# 18          /maturity                    NaN           2                2
# 19                  /                 /video           2                1
#
#     Unique Visitors  Site Bounce Rate Ø  Avg. Session Duration Ø  \
# 0                 1                   0                 0.003808
# 1                 1                   0                 0.021354
# 2                 2                   0                 0.000752
# 3                 1                   0                 0.000787
# 4                 1                   0                 0.000787
# 5                 1                   0                 0.000498
# 6                 1                   0                 0.002535
# 7                 2                   1                 0.000000
# 8                 1                   0                 0.001806
# 9                 1                   0                 0.006030
# 10                1                   0                 0.000428
# 11                1                   0                 0.000949
# 12                1                   0                 0.000613
# 13                1                   0                 0.017731
# 14                1                   0                 0.000949
# 15                2                   1                 0.000000
# 16                1                   0                 0.010741
# 17                1                   0                 0.002164
# 18                2                   0                 0.002639
# 19                1                   0                 0.017731
#
#     Avg. Time on Page Ø  Avg. Pages per Session Ø
# 0              0.000272                       1.0
# 1              0.002581                       1.0
# 2              0.000000                       1.0
# 3              0.000000                       1.0
# 4              0.000064                       2.0
# 5              0.000054                       2.0
# 6              0.000380                       1.0
# 7              0.000000                       1.0
# 8              0.000000                       1.0
# 9              0.000000                       1.0
# 10             0.000116                       2.0
# 11             0.000052                       1.0
# 12             0.000185                       2.0
# 13             0.000026                       2.0
# 14             0.000168                       2.0
# 15             0.000000                       1.0
# 16             0.000000                       2.0
# 17             0.000000                       2.0
# 18             0.000284                       2.0
# 19             0.001262                       2.0

# %% [markdown]
# Drop rows containing only NaN data and print how much data has been dropped/kept. Also drop columns containing unnecessary data that can easily be deduced from other columns.

# %%
reject = traffic_raw['Page Path Ø'].isna().sum()
total = traffic_raw['Page Path Ø'].notna().sum()
traffic = traffic_raw.copy()
traffic.dropna(subset=['Page Path Ø'], inplace=True)
print('\33[91;1m', 'Insufficient data on', reject, 'visitors', '\33[0m')
print('\33[91;1m', 'Analysing', total, 'visitors', '\33[0m')

traffic.drop(['Page URL', 'Region', 'Referring URL'], axis=1, inplace=True)
traffic.head(20)
# Out:
#  Insufficient data on 181 visitors
#  Analysing 311 visitors
#            Day New or Returning Visitor Referring Category Ø Referring Site Ø  \
# 0   20/05/2020        Returning Visitor               Direct           Direct
# 1   22/05/2020        Returning Visitor               Direct           Direct
# 2   05/05/2020              New Visitor               Social     facebook.com
# 3   05/05/2020              New Visitor               Social     facebook.com
# 4   05/05/2020              New Visitor               Social     facebook.com
# 5   07/10/2020              New Visitor       Organic Search       google.com
# 6   05/05/2020              New Visitor               Social     facebook.com
# 7   04/01/2021              New Visitor               Direct           Direct
# 8   23/05/2020        Returning Visitor               Direct           Direct
# 9   07/06/2020        Returning Visitor               Direct           Direct
# 10  10/12/2020              New Visitor               Social     facebook.com
# 11  20/06/2020        Returning Visitor  Wix Email Marketing              NaN
# 12  17/11/2020              New Visitor               Social     facebook.com
# 13  01/05/2020        Returning Visitor               Direct           Direct
# 14  19/10/2020              New Visitor       Organic Search       google.com
# 15  01/11/2020              New Visitor       Organic Search        baidu.com
# 16  02/05/2020        Returning Visitor               Direct           Direct
# 17  05/05/2020              New Visitor               Social     facebook.com
# 18  05/05/2020              New Visitor               Direct           Direct
# 19  01/05/2020        Returning Visitor               Direct           Direct
#
#                      UTM Campaign Name Ø UTM Campaign Medium Ø  \
# 0                                      _                     _
# 1                                      _                     _
# 2                                      _                     _
# 3                                      _                     _
# 4                                      _                     _
# 5                                      _                     _
# 6                                      _                     _
# 7                                      _                     _
# 8                                      _                     _
# 9                                      _                     _
# 10                                     _                     _
# 11  d5328aae-be6f-4dbc-a1c5-9886f145f202                  mail
# 12                                     _                     _
# 13                                     _                     _
# 14                                     _                     _
# 15                                     _                     _
# 16                                     _                     _
# 17                                     _                     _
# 18                                     _                     _
# 19                                     _                     _
#
#    UTM Campaign Source Ø    Page Path Ø         Country        City  \
# 0                      _      /maturity  United Kingdom      London
# 1                      _  /early-access  United Kingdom   Greenwich
# 2                      _              /  United Kingdom    Brighton
# 3                      _         /video  United Kingdom    Brighton
# 4                      _              /  United Kingdom    Brighton
# 5                      _         /video         Germany      Berlin
# 6                      _         /video  United Kingdom      London
# 7                      _              /             NaN         NaN
# 8                      _              /  United Kingdom   Greenwich
# 9                      _     /exclusive  United Kingdom         NaN
# 10                     _         /video  United Kingdom    Brighton
# 11                    so  /early-access  United Kingdom         NaN
# 12                     _      /maturity  United Kingdom    Brighton
# 13                     _         /video  United Kingdom         NaN
# 14                     _      /maturity  United Kingdom     Glasgow
# 15                     _              /           China     Hongkou
# 16                     _              /  United Kingdom         NaN
# 17                     _              /  United Kingdom  Bermondsey
# 18                     _              /  United Kingdom   Islington
# 19                     _      /maturity  United Kingdom         NaN
#
#    Device Type Browser Browser Version Operating System  \
# 0      Desktop  Chrome   81.0.4044.138          Windows
# 1      Desktop  Chrome   81.0.4044.138          Windows
# 2       Mobile  Safari             NaN           Mac OS
# 3       Mobile  Chrome  268.1.0.54.121          Android
# 4       Mobile  Chrome  268.1.0.54.121          Android
# 5      Desktop  Chrome   83.0.4103.116            Linux
# 6       Mobile  Chrome   81.0.4044.117          Android
# 7      Desktop  Chrome     71.0.3563.0            Linux
# 8      Desktop  Chrome   81.0.4044.138          Windows
# 9      Desktop  Chrome    83.0.4103.97          Windows
# 10     Desktop  Chrome    87.0.4280.88           Mac OS
# 11     Desktop  Chrome   83.0.4103.106          Windows
# 12     Desktop  Chrome   86.0.4240.198           Mac OS
# 13     Desktop  Chrome   81.0.4044.129          Windows
# 14      Tablet  Chrome    85.0.4183.92              iOS
# 15      Mobile  Chrome   57.0.2987.108          Android
# 16      Mobile  Chrome   81.0.4044.117          Android
# 17      Mobile  Chrome  268.1.0.54.121          Android
# 18      Mobile  Safari          13.0.5           Mac OS
# 19     Desktop  Chrome   81.0.4044.129          Windows
#
#    Is the First Page Viewed Ø (Yes / No) Is the Last Page Viewed Ø (Yes / No)  \
# 0                                    Yes                                  Yes
# 1                                    Yes                                   No
# 2                                    Yes                                  Yes
# 3                                     No                                  Yes
# 4                                    Yes                                   No
# 5                                     No                                   No
# 6                                     No                                  Yes
# 7                                    Yes                                  Yes
# 8                                     No                                  Yes
# 9                                    Yes                                  Yes
# 10                                    No                                   No
# 11                                   Yes                                   No
# 12                                    No                                   No
# 13                                    No                                   No
# 14                                    No                                   No
# 15                                   Yes                                  Yes
# 16                                   Yes                                   No
# 17                                   Yes                                  Yes
# 18                                   Yes                                   No
# 19                                    No                                   No
#
#    Next Page Viewed Ø Previous Page Viewed Ø  Page Views  Site Sessions Ø  \
# 0                 NaN                    NaN           7                1
# 1          /exclusive                    NaN           5                1
# 2                 NaN                    NaN           4                2
# 3                 NaN                      /           3                2
# 4              /video                    NaN           3                2
# 5               /news              /maturity           3                1
# 6                 NaN                      /           3                1
# 7                 NaN                    NaN           2                2
# 8                 NaN              /maturity           2                1
# 9                 NaN                    NaN           2                1
# 10             /about                      /           2                1
# 11         /exclusive                    NaN           2                1
# 12             /video                      /           2                1
# 13          /maturity                  /news           2                1
# 14             /video                      /           2                1
# 15                NaN                    NaN           2                2
# 16          /maturity                    NaN           2                1
# 17                NaN                    NaN           2                1
# 18          /maturity                    NaN           2                2
# 19                  /                 /video           2                1
#
#     Unique Visitors  Site Bounce Rate Ø  Avg. Session Duration Ø  \
# 0                 1                   0                 0.003808
# 1                 1                   0                 0.021354
# 2                 2                   0                 0.000752
# 3                 1                   0                 0.000787
# 4                 1                   0                 0.000787
# 5                 1                   0                 0.000498
# 6                 1                   0                 0.002535
# 7                 2                   1                 0.000000
# 8                 1                   0                 0.001806
# 9                 1                   0                 0.006030
# 10                1                   0                 0.000428
# 11                1                   0                 0.000949
# 12                1                   0                 0.000613
# 13                1                   0                 0.017731
# 14                1                   0                 0.000949
# 15                2                   1                 0.000000
# 16                1                   0                 0.010741
# 17                1                   0                 0.002164
# 18                2                   0                 0.002639
# 19                1                   0                 0.017731
#
#     Avg. Time on Page Ø  Avg. Pages per Session Ø
# 0              0.000272                       1.0
# 1              0.002581                       1.0
# 2              0.000000                       1.0
# 3              0.000000                       1.0
# 4              0.000064                       2.0
# 5              0.000054                       2.0
# 6              0.000380                       1.0
# 7              0.000000                       1.0
# 8              0.000000                       1.0
# 9              0.000000                       1.0
# 10             0.000116                       2.0
# 11             0.000052                       1.0
# 12             0.000185                       2.0
# 13             0.000026                       2.0
# 14             0.000168                       2.0
# 15             0.000000                       1.0
# 16             0.000000                       2.0
# 17             0.000000                       2.0
# 18             0.000284                       2.0
# 19             0.001262                       2.0

# %% [markdown]
# Convert remaining columns into appropriate data types.
#
# Session duration and page time columns are in units of days, convert to seconds and update column names.
#
# Set 'Day' as index and sort by date.
#
# Assign 'max_date' as the date at which the data was obtained.

# %%
num = ['Page Views', 'Site Sessions Ø', 'Unique Visitors', 'Site Bounce Rate Ø',
       'Avg. Session Duration Ø', 'Avg. Time on Page Ø']
bina = ['Is the Last Page Viewed Ø (Yes / No)', 'Is the First Page Viewed Ø (Yes / No)']
time = ['Avg. Session Duration Ø', 'Avg. Time on Page Ø']

traffic[num] = traffic[num].apply(pd.to_numeric)
traffic['Avg. Pages per Session Ø'] = traffic['Avg. Pages per Session Ø'].astype('int64')
traffic[time] = traffic[time].apply(lambda x: x*24*60*60)
traffic.rename(columns=lambda x: x[:-2] + ' (s)' if x in time else x, inplace=True)

for i in bina:
    d = {'No': 0, 'Yes': 1}
    traffic[i] = traffic[i].map(d)
    traffic[i] = traffic[i].astype('bool')
    traffic.rename(columns={i:i[7:-13]}, inplace=True)
    
traffic['Day'] = pd.to_datetime(traffic['Day'], format='%d/%m/%Y')
traffic = traffic.set_index('Day').sort_index()

max_date = str(max(traffic.index))[0:10]
traffic.head(20)
# Out:
#            New or Returning Visitor Referring Category Ø Referring Site Ø  \
# Day
# 2020-05-01        Returning Visitor               Direct           Direct
# 2020-05-01        Returning Visitor               Direct           Direct
# 2020-05-01              New Visitor               Direct           Direct
# 2020-05-01              New Visitor               Direct           Direct
# 2020-05-01        Returning Visitor               Direct           Direct
# 2020-05-01        Returning Visitor               Direct           Direct
# 2020-05-01        Returning Visitor               Direct           Direct
# 2020-05-01              New Visitor               Direct           Direct
# 2020-05-01              New Visitor               Direct           Direct
# 2020-05-01        Returning Visitor               Direct           Direct
# 2020-05-01              New Visitor               Direct           Direct
# 2020-05-01              New Visitor               Direct           Direct
# 2020-05-01        Returning Visitor               Direct           Direct
# 2020-05-01              New Visitor               Social     facebook.com
# 2020-05-01              New Visitor               Direct           Direct
# 2020-05-01        Returning Visitor               Direct           Direct
# 2020-05-01        Returning Visitor               Direct           Direct
# 2020-05-01              New Visitor               Direct           Direct
# 2020-05-01        Returning Visitor               Direct           Direct
# 2020-05-01        Returning Visitor               Direct           Direct
#
#            UTM Campaign Name Ø UTM Campaign Medium Ø UTM Campaign Source Ø  \
# Day
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
# 2020-05-01                   _                     _                     _
#
#            Page Path Ø         Country          City Device Type Browser  \
# Day
# 2020-05-01           /  United Kingdom           NaN      Mobile  Chrome
# 2020-05-01      /about  United Kingdom           NaN     Desktop  Chrome
# 2020-05-01           /  United Kingdom      Brighton      Mobile  Safari
# 2020-05-01      /video  United Kingdom      Brighton     Desktop  Chrome
# 2020-05-01       /news  United Kingdom           NaN     Desktop  Chrome
# 2020-05-01           /  United Kingdom           NaN     Desktop  Chrome
# 2020-05-01       /news  United Kingdom           NaN     Desktop  Chrome
# 2020-05-01   /maturity  United Kingdom      Brighton     Desktop  Chrome
# 2020-05-01           /  United Kingdom  Burgess Hill      Mobile  Safari
# 2020-05-01           /  United Kingdom           NaN     Desktop  Chrome
# 2020-05-01      /about  United Kingdom  Burgess Hill      Mobile  Safari
# 2020-05-01   /maturity  United Kingdom  Burgess Hill      Mobile  Safari
# 2020-05-01    /contact  United Kingdom           NaN     Desktop  Chrome
# 2020-05-01      /video  United Kingdom      Wivenhoe      Mobile  Chrome
# 2020-05-01       /news  United Kingdom      Brighton     Desktop  Chrome
# 2020-05-01   /maturity  United Kingdom           NaN     Desktop  Chrome
# 2020-05-01       /news  United Kingdom           NaN     Desktop  Chrome
# 2020-05-01           /  United Kingdom      Brighton     Desktop  Chrome
# 2020-05-01           /  United Kingdom           NaN     Desktop  Chrome
# 2020-05-01    /contact  United Kingdom           NaN     Desktop  Chrome
#
#            Browser Version Operating System  First Page Viewed  \
# Day
# 2020-05-01   81.0.4044.117          Android               True
# 2020-05-01   81.0.4044.129          Windows              False
# 2020-05-01  261.1.0.57.120           Mac OS               True
# 2020-05-01   81.0.4044.122          Windows              False
# 2020-05-01   81.0.4044.129          Windows              False
# 2020-05-01   81.0.4044.129          Windows              False
# 2020-05-01   81.0.4044.129          Windows              False
# 2020-05-01   81.0.4044.122          Windows              False
# 2020-05-01  262.1.0.71.117           Mac OS               True
# 2020-05-01   81.0.4044.129          Windows              False
# 2020-05-01  262.1.0.71.117           Mac OS              False
# 2020-05-01  262.1.0.71.117           Mac OS              False
# 2020-05-01   81.0.4044.129          Windows              False
# 2020-05-01  239.1.0.17.119          Android              False
# 2020-05-01   81.0.4044.122          Windows              False
# 2020-05-01   81.0.4044.129          Windows              False
# 2020-05-01   81.0.4044.129          Windows              False
# 2020-05-01   81.0.4044.122          Windows              False
# 2020-05-01   81.0.4044.129          Windows              False
# 2020-05-01   81.0.4044.129          Windows              False
#
#             Last Page Viewed Next Page Viewed Ø Previous Page Viewed Ø  \
# Day
# 2020-05-01             False          /maturity                    NaN
# 2020-05-01             False              /news                      /
# 2020-05-01              True                NaN                    NaN
# 2020-05-01             False              /news              /maturity
# 2020-05-01             False             /about                 /video
# 2020-05-01             False             /about               /contact
# 2020-05-01             False             /video               /contact
# 2020-05-01             False             /video                      /
# 2020-05-01             False          /maturity                    NaN
# 2020-05-01             False           /contact              /maturity
# 2020-05-01              True                NaN              /maturity
# 2020-05-01             False             /about                      /
# 2020-05-01             False                  /                 /about
# 2020-05-01             False                  /                      /
# 2020-05-01             False                  /                 /video
# 2020-05-01             False                  /                      /
# 2020-05-01             False             /video                 /about
# 2020-05-01              True                NaN                  /news
# 2020-05-01             False          /maturity              /maturity
# 2020-05-01             False              /news                      /
#
#             Page Views  Site Sessions Ø  Unique Visitors  Site Bounce Rate Ø  \
# Day
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   1
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
# 2020-05-01           1                1                1                   0
#
#             Avg. Session Duration (s)  Avg. Time on Page (s)  \
# Day
# 2020-05-01                 928.000022              464.01120
# 2020-05-01                1531.999958                4.49280
# 2020-05-01                   0.000000                0.00000
# 2020-05-01                 122.999990                2.50560
# 2020-05-01                1531.999958                4.01760
# 2020-05-01                1531.999958              194.48640
# 2020-05-01                1531.999958                2.50560
# 2020-05-01                 122.999990               52.01280
# 2020-05-01                1120.000003                5.67648
# 2020-05-01                1531.999958               10.49760
# 2020-05-01                1120.000003                0.00000
# 2020-05-01                1120.000003              551.49120
# 2020-05-01                1531.999958               29.50560
# 2020-05-01                  43.999978                1.51200
# 2020-05-01                 122.999990                1.51200
# 2020-05-01                1531.999958              527.99040
# 2020-05-01                1531.999958                1.98720
# 2020-05-01                 122.999990                0.00000
# 2020-05-01                1531.999958               13.99680
# 2020-05-01                1531.999958                5.01120
#
#             Avg. Pages per Session Ø
# Day
# 2020-05-01                         1
# 2020-05-01                         1
# 2020-05-01                         1
# 2020-05-01                         1
# 2020-05-01                         2
# 2020-05-01                         2
# 2020-05-01                         2
# 2020-05-01                         2
# 2020-05-01                         2
# 2020-05-01                         2
# 2020-05-01                         1
# 2020-05-01                         2
# 2020-05-01                         2
# 2020-05-01                         2
# 2020-05-01                         2
# 2020-05-01                         1
# 2020-05-01                         2
# 2020-05-01                         1
# 2020-05-01                         2
# 2020-05-01                         1

# %% [markdown]
# Plot data with seaborn.

# %%
sns.set()
plt.figure(figsize=(6, 6))
ax = sns.countplot(x="Device Type", data=traffic)
ax.set(xlabel='Device Type', ylabel='Visitors', title='Visitors per device type for jorjmakesmusic.com')

plt.show()

# %%
plt.figure(figsize=(16, 6))
ax = sns.countplot(x="Country", data=traffic)
ax.set(xlabel='Country', ylabel='Visitors', title='Visitors per Country for jorjmakesmusic.com')

plt.xticks(rotation=45)
plt.show()

# %%
ax = sns.countplot(x="New or Returning Visitor", data=traffic)
ax.set(xlabel=None, ylabel='Visitors', title='New or Returning Visitor?')

plt.show()

# %% [markdown]
# Website released 05/05/2020, any data prior to this is therefore of no relevance therefore, data rejected for 'visitor rate per day' graphs.

# %%
dayData = traffic.index.value_counts().sort_index()['2020-05-05':]

plt.figure(figsize=(16, 6))
ax = sns.lineplot(data=dayData)
ax.set(xlabel='Date', ylabel='Visitors', title='Visitors per Day for jorjmakesmusic.com')
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %y"))

plt.show()

# %%
dates = traffic.index.floor('D')
sessionTime = traffic.groupby(dates)['Avg. Session Duration (s)'].sum()

plt.figure(figsize=(16, 6))
ax = sns.lineplot(data=sessionTime)
ax.set(xlabel='Date', ylabel='Time (s)', title='Average Session Duration per day for jorjmakesmusic.com')
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %y"))

plt.show()

# %%
dates = traffic.index.floor('D')
pageTime = traffic.groupby(dates)['Avg. Time on Page (s)'].sum()

plt.figure(figsize=(16, 6))
ax = sns.lineplot(data=pageTime)
ax.set(xlabel='Date', ylabel='Time (s)', title='Average Time on Page per day for jorjmakesmusic.com')
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %y"))

plt.show()
